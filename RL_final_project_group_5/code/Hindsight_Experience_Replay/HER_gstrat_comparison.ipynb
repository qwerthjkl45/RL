# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

HER_plot_info_filename1 = "HER_plot_info_gstrat_final_mem_10k"
HER_plot_info_filename2 = "HER_plot_info_gstrat_random_mem_10k"
HER_plot_info_filename3 = "HER_plot_info_gstrat_episode_mem_10k"
HER_plot_info_filename4 = "HER_plot_info_gstrat_max_mem_10k"
HER_plot_info_filename5 = "HER_plot_info_gstrat_leftright_mem_10k"
HER_plot_info_filename6 = "HER_plot_info_gstrat_random_mult_4_mem_10k"
HER_plot_info_filename7 = "HER_plot_info_gstrat_episode_mult_4_mem_10k"

# Load
loaded_HER_plot_info1 = pickle.load(open(HER_plot_info_filename1, 'rb'))
loaded_HER_plot_info2 = pickle.load(open(HER_plot_info_filename2, 'rb'))
loaded_HER_plot_info3 = pickle.load(open(HER_plot_info_filename3, 'rb'))
loaded_HER_plot_info4 = pickle.load(open(HER_plot_info_filename4, 'rb'))
loaded_HER_plot_info5 = pickle.load(open(HER_plot_info_filename5, 'rb'))
loaded_HER_plot_info6 = pickle.load(open(HER_plot_info_filename6, 'rb'))
loaded_HER_plot_info7 = pickle.load(open(HER_plot_info_filename7, 'rb'))
loaded_HER_models_mean_epi_reward1,loaded_HER_models_epi_reward_std1 = loaded_HER_plot_info1
loaded_HER_models_mean_epi_reward2,loaded_HER_models_epi_reward_std2 = loaded_HER_plot_info2
loaded_HER_models_mean_epi_reward3,loaded_HER_models_epi_reward_std3 = loaded_HER_plot_info3
loaded_HER_models_mean_epi_reward4,loaded_HER_models_epi_reward_std4 = loaded_HER_plot_info4
loaded_HER_models_mean_epi_reward5,loaded_HER_models_epi_reward_std5 = loaded_HER_plot_info5
loaded_HER_models_mean_epi_reward6,loaded_HER_models_epi_reward_std6 = loaded_HER_plot_info6
loaded_HER_models_mean_epi_reward7,loaded_HER_models_epi_reward_std7 = loaded_HER_plot_info7


t = np.arange(0,500)
plt.figure(figsize=(9,5))
plt.errorbar(t,loaded_HER_models_mean_epi_reward1,loaded_HER_models_epi_reward_std1,
             color="b",ecolor="tomato",alpha=0.6,label="HER1")
#plt.errorbar(t,loaded_HER_models_mean_epi_reward2,loaded_HER_models_epi_reward_std2,
#             color="g",ecolor="tomato",alpha=0.0,label="HER2")
#plt.errorbar(t,loaded_HER_models_mean_epi_reward3,loaded_HER_models_epi_reward_std3,
#             color="r",ecolor="tomato",alpha=0.0,label="HER3")
plt.errorbar(t,loaded_HER_models_mean_epi_reward4,loaded_HER_models_epi_reward_std4,
             color="c",ecolor="tomato",alpha=0.6,label="HER4")
#plt.errorbar(t,loaded_HER_models_mean_epi_reward5,loaded_HER_models_epi_reward_std5,
#             color="m",ecolor="tomato",alpha=0.0,label="HER5")
#plt.errorbar(t,loaded_HER_models_mean_epi_reward6,loaded_HER_models_epi_reward_std6,
#             color="y",ecolor="tomato",alpha=0.0,label="HER6")
#plt.errorbar(t,loaded_HER_models_mean_epi_reward7,loaded_HER_models_epi_reward_std7,
#             color="k",ecolor="tomato",alpha=0.0,label="HER7")
#plt.plot(t,loaded_HER_models_mean_epi_reward1,color='r',label="HER1")
#plt.plot(t,loaded_HER_models_mean_epi_reward2,color='g',label="HER2")
#plt.plot(t,loaded_HER_models_mean_epi_reward3,color='b',label="HER3")
#plt.plot(t,loaded_HER_models_mean_epi_reward4,color='y',label="HER4")
#plt.plot(t,loaded_HER_models_mean_epi_reward5,color='m',label="HER5")
#plt.plot(t,loaded_HER_models_mean_epi_reward6,color='y',label="HER6")
#plt.plot(t,loaded_HER_models_mean_epi_reward7,color='k',label="HER7")
plt.legend()
plt.xlabel("Episode")
plt.ylabel("Average return")
plt.title("Average return per episode")
plt.show()

# %%
dist = 5
tot_num_points = int(500/dist)

Q_means_HER1 = []
Q_means_HER2 = []
Q_means_HER3 = []
Q_means_HER4 = []
Q_means_HER5 = []
Q_means_HER6 = []
Q_means_HER7 = []
Q_stds_HER1 = []
Q_stds_HER2 = []
Q_stds_HER3 = []
Q_stds_HER4 = []
Q_stds_HER5 = []
Q_stds_HER6 = []
Q_stds_HER7 = []

for k in range(0, tot_num_points):
    avg_kth_mean_HER1 = (1.0/dist) * np.sum(loaded_HER_models_mean_epi_reward1[k*dist:(k+1)*dist])
    avg_kth_mean_HER2 = (1.0/dist) * np.sum(loaded_HER_models_mean_epi_reward2[k*dist:(k+1)*dist])
    avg_kth_mean_HER3 = (1.0/dist) * np.sum(loaded_HER_models_mean_epi_reward3[k*dist:(k+1)*dist])
    avg_kth_mean_HER4 = (1.0/dist) * np.sum(loaded_HER_models_mean_epi_reward4[k*dist:(k+1)*dist])
    avg_kth_mean_HER5 = (1.0/dist) * np.sum(loaded_HER_models_mean_epi_reward5[k*dist:(k+1)*dist])
    avg_kth_mean_HER6 = (1.0/dist) * np.sum(loaded_HER_models_mean_epi_reward6[k*dist:(k+1)*dist])
    avg_kth_mean_HER7 = (1.0/dist) * np.sum(loaded_HER_models_mean_epi_reward7[k*dist:(k+1)*dist])
    Q_means_HER1.append(avg_kth_mean_HER1)
    Q_means_HER2.append(avg_kth_mean_HER2)
    Q_means_HER3.append(avg_kth_mean_HER3)
    Q_means_HER4.append(avg_kth_mean_HER4)
    Q_means_HER5.append(avg_kth_mean_HER5)
    Q_means_HER6.append(avg_kth_mean_HER6)
    Q_means_HER7.append(avg_kth_mean_HER7)
    avg_kth_std_HER1 = (1.0/dist) * np.sum(loaded_HER_models_epi_reward_std1[k*dist:(k+1)*dist])
    avg_kth_std_HER2 = (1.0/dist) * np.sum(loaded_HER_models_epi_reward_std2[k*dist:(k+1)*dist])
    avg_kth_std_HER3 = (1.0/dist) * np.sum(loaded_HER_models_epi_reward_std3[k*dist:(k+1)*dist])
    avg_kth_std_HER4 = (1.0/dist) * np.sum(loaded_HER_models_epi_reward_std4[k*dist:(k+1)*dist])
    avg_kth_std_HER5 = (1.0/dist) * np.sum(loaded_HER_models_epi_reward_std5[k*dist:(k+1)*dist])
    avg_kth_std_HER6 = (1.0/dist) * np.sum(loaded_HER_models_epi_reward_std6[k*dist:(k+1)*dist])
    avg_kth_std_HER7 = (1.0/dist) * np.sum(loaded_HER_models_epi_reward_std7[k*dist:(k+1)*dist])
    Q_stds_HER1.append(avg_kth_std_HER1)
    Q_stds_HER2.append(avg_kth_std_HER2)
    Q_stds_HER3.append(avg_kth_std_HER3)
    Q_stds_HER4.append(avg_kth_std_HER4)
    Q_stds_HER5.append(avg_kth_std_HER5)
    Q_stds_HER6.append(avg_kth_std_HER6)
    Q_stds_HER7.append(avg_kth_std_HER7)


t = np.arange(0,500,dist)
#plt.figure(figsize=(9,5))
#plt.errorbar(t,Q_means_HER,Q_stds_HER,
#             color="red",ecolor="tomato",alpha=0.6,label="HER")
plt.plot(t,Q_means_HER1,color='b',label="Final")
plt.plot(t,Q_means_HER2,color='g',label="Random")
plt.plot(t,Q_means_HER3,color='r',label="Episode")
plt.plot(t,Q_means_HER4,color='c',label="Max")
plt.plot(t,Q_means_HER5,color='m',label="Left-Right")
plt.plot(t,Q_means_HER6,color='y',label="Random-4")
plt.plot(t,Q_means_HER7,color='k',label="Episode-4")
plt.xlabel("Episode")
plt.ylabel("Average return")
plt.title("Average return per episode for different goal strategies")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

names_10k = [
"HER_plot_info_gstrat_final_mem_10k",
"HER_plot_info_gstrat_random_mem_10k",
"HER_plot_info_gstrat_episode_mem_10k",
"HER_plot_info_gstrat_max_mem_10k",
"HER_plot_info_gstrat_leftright_mem_10k",
"HER_plot_info_gstrat_random_mult_4_mem_10k",
"HER_plot_info_gstrat_episode_mult_4_mem_10k"
]
names_60k = [
"HER_plot_info_gstrat_final_mem_60k",
"HER_plot_info_gstrat_random_mem_60k",
"HER_plot_info_gstrat_episode_mem_60k",
"HER_plot_info_gstrat_max_mem_60k",
"HER_plot_info_gstrat_leftright_mem_60k",
"HER_plot_info_gstrat_random_mult_4_mem_60k",
"HER_plot_info_gstrat_episode_mult_4_mem_60k"
]

HER_plot_info_filename1 = names_10k[5]
HER_plot_info_filename2 = names_60k[5]


# Load
loaded_HER_plot_info1 = pickle.load(open(HER_plot_info_filename1, 'rb'))
loaded_HER_plot_info2 = pickle.load(open(HER_plot_info_filename2, 'rb'))
loaded_HER_models_mean_epi_reward1,loaded_HER_models_epi_reward_std1 = loaded_HER_plot_info1
loaded_HER_models_mean_epi_reward2,loaded_HER_models_epi_reward_std2 = loaded_HER_plot_info2



t = np.arange(0,500)
plt.figure(figsize=(9,5))
plt.errorbar(t,loaded_HER_models_mean_epi_reward1,loaded_HER_models_epi_reward_std1,
             color="blue",ecolor="lightblue",alpha=0.9,label="HER1")
plt.errorbar(t,loaded_HER_models_mean_epi_reward2,loaded_HER_models_epi_reward_std2,
             color="red",ecolor="tomato",alpha=0.6,label="HER2")
#plt.plot(t,loaded_HER_models_mean_epi_reward1,color='r',label="HER1")
#plt.plot(t,loaded_HER_models_mean_epi_reward2,color='g',label="HER2")
plt.legend()
plt.xlabel("Episode")
plt.ylabel("Average return")
plt.title("Average return per episode")
plt.show()

# %%
dist = 5
tot_num_points = int(500/dist)

Q_means_HER1 = []
Q_means_HER2 = []
Q_stds_HER1 = []
Q_stds_HER2 = []

for k in range(0, tot_num_points):
    avg_kth_mean_HER1 = (1.0/dist) * np.sum(loaded_HER_models_mean_epi_reward1[k*dist:(k+1)*dist])
    avg_kth_mean_HER2 = (1.0/dist) * np.sum(loaded_HER_models_mean_epi_reward2[k*dist:(k+1)*dist])
    Q_means_HER1.append(avg_kth_mean_HER1)
    Q_means_HER2.append(avg_kth_mean_HER2)
    avg_kth_std_HER1 = (1.0/dist) * np.sum(loaded_HER_models_epi_reward_std1[k*dist:(k+1)*dist])
    avg_kth_std_HER2 = (1.0/dist) * np.sum(loaded_HER_models_epi_reward_std2[k*dist:(k+1)*dist])
    Q_stds_HER1.append(avg_kth_std_HER1)
    Q_stds_HER2.append(avg_kth_std_HER2)

t = np.arange(0,500,dist)
#plt.figure(figsize=(9,5))
plt.errorbar(t,Q_means_HER1,Q_stds_HER1,
             color="blue",ecolor="lightblue",alpha=0.9,label="Memory size 10000")
plt.errorbar(t,Q_means_HER2,Q_stds_HER2,
             color="red",ecolor="tomato",alpha=0.6,label="Memory size 60000")
plt.legend(loc="upper left")
plt.xlabel("Episode")
plt.ylabel("Average return")
plt.title("Average return per episode for Random-4 strategy")
plt.show()
